# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitraj26/Rasayans2K24-DataVision/blob/main/Advanced_Data_Cleaning_and_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# read the dataset
df = pd.read_csv("Prayagraj_Traffic_Data.csv")
df.head(15)
# Out:
#     record_id            timestamp  intersection_id   intersection_name  \
# 0      9926.0  2023-01-07 21:20:00              6.0  Allahabad Junction
# 1      8595.0  2023-01-06 23:10:00              5.0        Naini Bridge
# 2       673.0  2023-01-01 11:10:00              3.0               Chowk
# 3      8744.0  2023-01-07 01:40:00              4.0         Tagore Town
# 4       316.0  2023-01-01 05:10:00              6.0  Allahabad Junction
# 5      1092.0  2023-01-01 18:10:00              2.0               Katra
# 6      3503.0  2023-01-03 10:20:00              3.0               Chowk
# 7      7477.0  2023-01-06 04:30:00              7.0           Phaphamau
# 8      2955.0  2023-01-03 01:10:00              5.0        Naini Bridge
# 9      6620.0  2023-01-05 14:10:00             10.0          Minto Park
# 10     4872.0  2023-01-04 09:10:00              2.0               Katra
# 11     6309.0  2023-01-05 09:00:00              9.0          MNNIT Gate
# ...

# %%
# getting info from the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10080 entries, 0 to 10079
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   record_id          9982 non-null   float64
#  1   timestamp          9983 non-null   object
#  2   intersection_id    9988 non-null   float64
#  3   intersection_name  9963 non-null   object
#  4   latitude           9974 non-null   float64
#  5   longitude          9964 non-null   float64
#  6   vehicle_count      9968 non-null   float64
#  7   average_speed      10006 non-null  float64
#  8   signal_cycle_time  9972 non-null   float64
#  9   green_time         9988 non-null   float64
#  10  yellow_time        9991 non-null   float64
#  11  red_time           9978 non-null   float64
#  12  weather_condition  10002 non-null  object
#  13  day_of_week        9986 non-null   object
#  14  is_holiday         9976 non-null   float64
# ...

# %%
# if we have special character like -- , ? in missing value place
# df.replace("?", np.nan, inplace = True)

# but in the data set it is already converted in Nan

# %%
# this code will check where the missing value is
missing_data = df.isnull()
missing_data.head(15)
# Out:
#     record_id  timestamp  intersection_id  intersection_name  latitude  \
# 0       False      False            False              False     False
# 1       False      False            False              False     False
# 2       False      False            False              False     False
# 3       False      False            False              False     False
# 4       False      False            False              False     False
# 5       False      False            False              False     False
# 6       False      False            False              False     False
# 7       False      False            False              False     False
# 8       False      False            False              False     False
# 9       False      False            False              False     False
# 10      False      False            False              False     False
# 11      False      False            False              False     False
# ...

# %%
# count the missing value in each column
for column in missing_data.columns:
    print(f"Column '{column}': {missing_data[column].value_counts()[True]} missing values")
# Out:
# Column 'record_id': 98 missing values
# Column 'timestamp': 97 missing values
# Column 'intersection_id': 92 missing values
# Column 'intersection_name': 117 missing values
# Column 'latitude': 106 missing values
# Column 'longitude': 116 missing values
# Column 'vehicle_count': 112 missing values
# Column 'average_speed': 74 missing values
# Column 'signal_cycle_time': 108 missing values
# Column 'green_time': 92 missing values
# Column 'yellow_time': 89 missing values
# Column 'red_time': 102 missing values
# Column 'weather_condition': 78 missing values
# Column 'day_of_week': 94 missing values
# Column 'is_holiday': 104 missing values
# Column 'event': 9220 missing values
# Column 'pollution_level': 105 missing values
# Column 'car_count': 97 missing values
# Column 'bus_count': 95 missing values
# Column 'truck_count': 106 missing values
# Column 'motorcycle_count': 100 missing values

# %%
df.isnull().sum()
# Out:
# record_id              98
# timestamp              97
# intersection_id        92
# intersection_name     117
# latitude              106
# longitude             116
# vehicle_count         112
# average_speed          74
# signal_cycle_time     108
# green_time             92
# yellow_time            89
# red_time              102
# weather_condition      78
# day_of_week            94
# is_holiday            104
# event                9220
# pollution_level       105
# car_count              97
# bus_count              95
# truck_count           106
# motorcycle_count      100
# dtype: int64

# %%
# now we have to replace nan value with mean,median & mode

avg_intersection_id = df["intersection_id"].astype('float').mean(axis=0).round(1)

# here axis=0 indicates that the mean should be calculated along the rows (i.e.,
# column-wise)

print("average :", avg_intersection_id)


# convert Nan value by mean
df["intersection_id"].replace(np.nan, avg_intersection_id, inplace = True)
# Out:
# average : 5.5
# <ipython-input-16-7b528898ccb7>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["intersection_id"].replace(np.nan, avg_intersection_id, inplace = True)

# %%
# similarly we can replace other column also

avg_latitude = df["latitude"].astype('float').mean(axis=0).round(4)
df["latitude"].replace(np.nan ,avg_latitude , inplace=True)

avg_longitude = df["longitude"].astype('float').mean(axis=0).round(4)
df["longitude"].replace(np.nan ,avg_longitude , inplace=True)

avg_vehicle_count = df["vehicle_count"].astype('float').mean(axis=0).round(0)
df["vehicle_count"].replace(np.nan , avg_vehicle_count ,inplace=True)

avg_average_speed = df["average_speed"].astype('float').mean(axis=0).round(2)
df["average_speed"].replace(np.nan , avg_average_speed ,inplace=True)

avg_signal_cycle_time = df["signal_cycle_time"].astype('float').mean(axis=0).round(1)
df["signal_cycle_time"].replace(np.nan , avg_signal_cycle_time , inplace=True)

avg_green_time = df["green_time"].astype('float').mean(axis=0).round(1)
df["green_time"].replace(np.nan , avg_green_time , inplace=True)

avg_yellow_time = df["yellow_time"].astype('float').mean(axis=0).round(1)
df["yellow_time"].replace(np.nan , avg_yellow_time , inplace=True)

avg_red_time = df["red_time"].astype('float').mean(axis=0).round(1)
df["red_time"].replace(np.nan , avg_red_time , inplace=True)

avg_pollution_level = df["pollution_level"].astype('float').mean(axis=0).round(2)
df["pollution_level"].replace(np.nan , avg_pollution_level , inplace=True)

avg_car_count = df["car_count"].astype('float').mean(axis=0).round(0)
df["car_count"].replace(np.nan , avg_car_count , inplace=True)

avg_bus_count = df["bus_count"].astype('float').mean(axis=0).round(0)
df["bus_count"].replace(np.nan , avg_bus_count , inplace=True)

avg_truck_count = df["truck_count"].astype('float').mean(axis=0).round(0)
df["truck_count"].replace(np.nan , avg_truck_count , inplace=True)

avg_motorcycle_count = df["motorcycle_count"].astype('float').mean(axis=0).round(0)
df["motorcycle_count"].replace(np.nan , avg_motorcycle_count , inplace=True)
# Out:
# <ipython-input-17-89274676d98f>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["latitude"].replace(np.nan ,avg_latitude , inplace=True)
# <ipython-input-17-89274676d98f>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# record_id              98
# timestamp              97
# intersection_id         0
# intersection_name     117
# latitude                0
# longitude               0
# vehicle_count           0
# average_speed           0
# signal_cycle_time       0
# green_time              0
# yellow_time             0
# red_time                0
# weather_condition      78
# day_of_week            94
# is_holiday            104
# event                9220
# pollution_level         0
# car_count               0
# bus_count               0
# truck_count             0
# motorcycle_count        0
# dtype: int64

# %%
# now replace the nan value with most frequent values

df['intersection_name'].value_counts().idxmax()
# Out:
# 'Chowk'

# %%
df["intersection_name"].replace(np.nan , "Chowk" , inplace=True)
# Out:
# <ipython-input-20-d0d4dec80f14>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["intersection_name"].replace(np.nan , "Chowk" , inplace=True)

# %%
df["weather_condition"].value_counts().idxmax()
# Out:
# 'Clear'

# %%
df["weather_condition"].replace(np.nan, "Clear" , inplace=True)
# Out:
# <ipython-input-22-e2a0247f1bce>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["weather_condition"].replace(np.nan, "Clear" , inplace=True)

# %%
df["day_of_week"].value_counts().idxmax()
# Out:
# 'Thursday'

# %%
df["day_of_week"].replace(np.nan,"Thrusday" , inplace=True)
# Out:
# <ipython-input-24-3e28fac035f8>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["day_of_week"].replace(np.nan,"Thrusday" , inplace=True)

# %%
df["is_holiday"].value_counts().idxmax()
# Out:
# 0.0

# %%
df["is_holiday"].replace(np.nan , 0.0 , inplace=True)
# Out:
# <ipython-input-26-8962413bcf54>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["is_holiday"].replace(np.nan , 0.0 , inplace=True)

# %%
# Replacing Nan value of event with No event
df["event"].replace(np.nan , "No Event" , inplace=True)
# Out:
# <ipython-input-27-b93f7584eb2f>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["event"].replace(np.nan , "No Event" , inplace=True)

# %%
# we cannot find timestamp using mean , median & mode

df = df.dropna(subset=['timestamp'])

# %%
# Convert the timestamp column to datetime format:
df['timestamp'] = pd.to_datetime(df['timestamp'])

# extract hours from timestamp
df['hour_of_day'] = df['timestamp'].dt.hour


df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9983 entries, 0 to 10079
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   record_id          9886 non-null   float64
#  1   timestamp          9983 non-null   datetime64[ns]
#  2   intersection_id    9983 non-null   float64
#  3   intersection_name  9983 non-null   object
#  4   latitude           9983 non-null   float64
#  5   longitude          9983 non-null   float64
#  6   vehicle_count      9983 non-null   float64
#  7   average_speed      9983 non-null   float64
#  8   signal_cycle_time  9983 non-null   float64
#  9   green_time         9983 non-null   float64
#  10  yellow_time        9983 non-null   float64
#  11  red_time           9983 non-null   float64
#  12  weather_condition  9983 non-null   object
#  13  day_of_week        9983 non-null   object
#  14  is_holiday         9983 non-null   float64
# ...

# %%
import seaborn as sns

# %%
sns.distplot(df['vehicle_count'])
# Out:
# <ipython-input-33-89ecec4bd46c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['vehicle_count'])
# <Axes: xlabel='vehicle_count', ylabel='Density'>

# %%
# IQR(Inter Quantile Range)
q1 = df['vehicle_count'].quantile(0.25)
q3 = df['vehicle_count'].quantile(0.75)
iqr = q3-q1

q1,q3,iqr
# Out:
# (68.0, 140.0, 72.0)

# %%
upper_limit = q3 + (1.5*iqr)
lower_limit = q1 - (1.5*iqr)
lower_limit,upper_limit
# Out:
# (-40.0, 248.0)

# %%
sns.boxplot(df['vehicle_count'])
# Out:
# <Axes: ylabel='vehicle_count'>

# %%
# find the outliers
df.loc[(df['vehicle_count'] > upper_limit) | (df['vehicle_count'] < lower_limit)]
# Out:
#        record_id           timestamp  intersection_id   intersection_name  \
# 45        7707.0 2023-01-06 08:20:00              7.0           Phaphamau
# 130       4980.0 2023-01-04 10:50:00             10.0          Minto Park
# 173       1955.0 2023-01-02 08:30:00              5.0        Naini Bridge
# 177       5346.0 2023-01-04 17:00:00              6.0  Allahabad Junction
# 229       4747.0 2023-01-04 07:00:00              7.0           Phaphamau
# ...          ...                 ...              ...                 ...
# 9953      9661.0 2023-01-07 17:00:00              1.0         Civil Lines
# 10011     4013.0 2023-01-03 18:50:00              3.0               Chowk
# 10024     9813.0 2023-01-07 19:30:00              3.0               Chowk
# 10041     3910.0 2023-01-03 17:00:00             10.0          Minto Park
# 10078     5489.0 2023-01-04 19:20:00              9.0          MNNIT Gate
#
#        latitude  longitude  vehicle_count  average_speed  signal_cycle_time  \
# ...

# %%
# trimming the outlier
new_df = df.loc[(df['vehicle_count'] < upper_limit) & (df['vehicle_count'] > lower_limit)]
print('before removing outlier : ',len(df))
print('after removing outlier : ',len(new_df))
print('outliers : ',len(df) - len(new_df))
# Out:
# before removing outlier :  9983
# after removing outlier :  9626
# outliers :  357

# %%
sns.boxplot(new_df['vehicle_count'])
# Out:
# <Axes: ylabel='vehicle_count'>

# %%
# capping - change the outlier value to upper or lower value
new_df = df.copy()
new_df.loc[(new_df['vehicle_count'] > upper_limit) , 'vehicle_count'] = upper_limit
new_df.loc[(new_df['vehicle_count'] < lower_limit) , 'vehicle_count'] = lower_limit

# %%
sns.boxplot(new_df['vehicle_count'])
# Out:
# <Axes: ylabel='vehicle_count'>

# %%
# similar steps we have follow for average speed
sns.distplot(df['average_speed'])
# Out:
# <ipython-input-42-ef060a3d54fa>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['average_speed'])
# <Axes: xlabel='average_speed', ylabel='Density'>

# %%
# IQR
q1 = df['average_speed'].quantile(0.25)
q3 = df['average_speed'].quantile(0.75)
iqr = q3-q1

q1,q3,iqr
# Out:
# (28.83, 38.31, 9.480000000000004)

# %%
upper_limit = q3 + (1.5*iqr)
lower_limit = q1 - (1.5*iqr)
lower_limit,upper_limit
# Out:
# (14.609999999999992, 52.53000000000001)

# %%
sns.boxplot(df['average_speed'])
# Out:
# <Axes: ylabel='average_speed'>

# %%
# find the outliers
df.loc[(df['average_speed'] > upper_limit) | (df['average_speed'] < lower_limit)]
# Out:
#        record_id           timestamp  intersection_id   intersection_name  \
# 2          673.0 2023-01-01 11:10:00              3.0               Chowk
# 17        8006.0 2023-01-06 13:20:00              6.0  Allahabad Junction
# 25         296.0 2023-01-01 04:50:00              6.0  Allahabad Junction
# 45        7707.0 2023-01-06 08:20:00              7.0           Phaphamau
# 50        7483.0 2023-01-06 04:40:00              3.0               Chowk
# ...          ...                 ...              ...                 ...
# 9953      9661.0 2023-01-07 17:00:00              1.0         Civil Lines
# 10024     9813.0 2023-01-07 19:30:00              3.0               Chowk
# 10043     9788.0 2023-01-07 19:00:00              8.0              Jhunsi
# 10074      777.0 2023-01-01 12:50:00              7.0           Phaphamau
# 10076     6662.0 2023-01-05 15:00:00              2.0               Katra
#
#        latitude  longitude  vehicle_count  average_speed  signal_cycle_time  \
# ...

# %%
# trimming the outlier
new_df = df.loc[(df['average_speed'] < upper_limit) & (df['average_speed'] > lower_limit)]
print('before removing outlier : ',len(df))
print('after removing outlier : ',len(new_df))
print('outliers : ',len(df) - len(new_df))
# Out:
# before removing outlier :  9983
# after removing outlier :  9767
# outliers :  216

# %%
sns.boxplot(new_df['average_speed'])
# Out:
# <Axes: ylabel='average_speed'>

# %%
# capping - change the outlier value to upper or lower value
new_df = df.copy()
new_df.loc[(new_df['average_speed'] > upper_limit) , 'average_speed'] = upper_limit.round(2)
new_df.loc[(new_df['average_speed'] < lower_limit) , 'average_speed'] = lower_limit.round(2)

# %%
sns.boxplot(new_df['average_speed'])
# Out:
# <Axes: ylabel='average_speed'>

# %%
# new_df.to_csv('Cleaned Data.csv')
new_df.head()
